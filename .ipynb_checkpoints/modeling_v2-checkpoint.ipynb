# %% [markdown]
# # Modeling - *Phragmites australis*
#
# All image files are stored locally.
#
# This notebook represents initial supervised modeling efforts to classify *phragmites australis* from aerial images. To create an environment to run this code, please see the requirements.txt file.

# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl
import rasterio as rio
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep

import sklearn as sk
from sklearn.model_selection import train_test_split

import tensorflow as tf


mpl.rcParams['figure.figsize'] = (10, 10)
mpl.rcParams['axes.titlesize'] = 20

# %% [markdown]
# # Import Training Data

# %% [markdown]
# Examination of the training data. This is from local files as the images are too large to be on Github.

# %%
train_directory = './new_train_data/images/'

#Grab the images
image_path = []

for file in os.listdir(train_directory):
    filename = os.fsdecode(file)
    image_path.append(train_directory + filename)

#Sort the Files
image_path = sorted(image_path)

# %%
#Do the paths to the files look alright? 
image_path[48]
# Out:
# './new_train_data/images/000000048.tif'

# %%
#Running tests on example: 000000048.tif, this image should include Phragmites
with rio.open(image_path[48], 'r+') as src:
    test_image = src.read()
    test_image_meta = src.meta
    
    #Remove the null portion of the image: 6
    test_image = test_image[:5][:][:]

# %%
print("The shape of the training image is {0} by {1} by {2}".format(test_image.shape[0],
                                                                    test_image.shape[1],test_image.shape[2]))
# Out:
# The shape of the training image is 5 by 32 by 32

# %%
#Let's plot this example:
titles = ["Red", "Green", "Blue", "Red-Edge", "NIR"]
ep.plot_bands(test_image,
              scale=False,
             title=titles)
plt.show()

# %% [markdown]
# **Segmentation Classes:**
#
# Within each image there are several different classes including water, soil, algae, bulrush, cattail and the invasive species of interest *Phragmites australis*. Initially, we will only try to predict this class, but in the future may move to segmentation of all labeled classes.

# %%
#Let's see if we can visualize what a label looks like: 
label_directory = './new_train_data/labels/Phragmites/'
phrag_label_path = []

for file in os.listdir(label_directory):
    filename = os.fsdecode(file)
    phrag_label_path.append(label_directory + filename)

phrag_label_path = sorted(phrag_label_path)

# %%
#Check it matches:
print('Percentage of data with phragmites label: {0}'.format(len(phrag_label_path)/len(image_path)))
# Out:
# Percentage of data with phragmites label: 0.6594094840441396

# %%
phrag_label_path[0]
# Out:
# './new_train_data/labels/Phragmites/000000048.tif'

# %%
#Running tests on example: 000000007
with rio.open(phrag_label_path[0], 'r+') as src:
    test_label = src.read()
    test_label_meta = src.meta

# %%
print("The shape of the training mask is {0} by {1} by {2}".format(test_label.shape[0],
                                                                    test_label.shape[1],test_label.shape[2]))
# Out:
# The shape of the training mask is 1 by 32 by 32

# %%
import numpy as np
masked = np.ma.masked_where(test_label[0] == 0, test_label[0])
f, ax = plt.subplots(1, 1)

#Plot the image
ep.plot_rgb(test_image,ax =ax,stretch = True,rgb=[0,1,2],)

#Plot the Mask
ax.imshow(masked, 'jet', interpolation='none', alpha=0.7)

#Plot settings
ax.set_title("Image with Phrag Mask")
plt.show()

# %% [markdown]
# **Conclusion**
#
# Herein, we've collected the paths to both the 5x32x32 images and the corresponding 1x32x32 images. We've checked to ensure the labels correspond to images. We have selected only one class for initial training, with option to predict all classes in the future. Of note, only ~70% of images have phragmites within them. This may lead to some overfitting. We may consider using image rotations to create "new images' with no phragmites to balance the training data.

# %% [markdown]
# # Data Preperation:
#
# This step represents the collection and processing of all images. For best ease with processing in Keras, we reformat the images to be of dimension (N x X x Y x channels)

# %%
#Grab and process the images: 
images = []
image_name = []

for image in image_path:
    image_name.append(image.split('images/')[1])
    with rio.open(image, 'r+') as src:
        images.append(np.transpose(src.read(), (1, 2, 0)))
        
images = np.array(images)

#Take only five channels
images = images[:,:,:,:5]

# %%
#Data Follows format: Example number, image x pixesl, image y pixels and chanels
images.shape
# Out:
# (3353, 32, 32, 5)

# %% [markdown]
# Some masks have several layers and mixed values (0-5). This appears to simply be a result of data export from arcGIS. To correct these labels, we first flatten the matrix so it is of dimension 1x32x32 then allocate all values above 1 to become 1. This creates binary masks.

# %%
phrag_masks = []
phrag_name = []

for mask in phrag_label_path:
    phrag_name.append(mask.split('Phragmites/')[1])
    
    #append the mask:
    with rio.open(mask, 'r+') as src:
        #Flatten and make anything above 1 =1 
        temp  = np.sum(src.read(),axis = 0).reshape(32,32,1)
        temp[temp>1] = 1
        phrag_masks.append(temp)

        
        
phrag_masks = np.array(phrag_masks)

#Let's Look at the shape
phrag_masks.shape
# Out:
# (2211, 32, 32, 1)

# %%
images.shape[0] - phrag_masks.shape[0]
# Out:
# 1142

# %%
phrag_mask_fill = []
phrag_count = 0 

#We to back fill masks for all the images which don't have labels
for image in image_name:
    #Create null
    if image not in phrag_name:
        phrag_mask_fill.append(np.zeros([32,32,1]))
        
    #Replace otherwise
    else: 
        phrag_mask_fill.append(phrag_masks[phrag_count])
        phrag_count +=1
        
phrag_mask_fill = np.array(phrag_mask_fill)

# %%
phrag_mask_fill.shape
# Out:
# (3353, 32, 32, 1)

# %%
#Double Check!
masked = np.ma.masked_where(phrag_mask_fill[48,:,:].reshape(32,32) == 0, phrag_mask_fill[48,:,:].reshape(32,32))
f, ax = plt.subplots(1, 1)

#Plot the image
ep.plot_rgb(np.transpose(images[48], (2,0,1)),ax =ax,stretch = True,rgb=[0,1,2],)

#Plot the Mask
ax.imshow(masked, 'jet', interpolation='none', alpha=0.7)

#Plot settings
ax.set_title("Image with Phrag Mask")
plt.show()

# %% [markdown]
# # Descriptive Statatistics
#
# **How many images have the plant of interest within?**

# %%
fig,ax = plt.subplots(1,figsize=(3, 6))
ax.bar(['Contain P. Australis','No label'],[phrag_masks.shape[0],images.shape[0]-phrag_masks.shape[0]])
ax.set_title('Label Balance in Dataset')
# Out:
# Text(0.5, 1.0, 'Label Balance in Dataset')

# %% [markdown]
# **Conclusion**
#
# We have not explored the details of the data well. We will attempt to perform so more basic analysis on the images to see if there are any existing artifacts which need attention. If we introduce more classes for prediction, we will add more bar graphs as well.

# %% [markdown]
# # Feature Engineering:

# %% [markdown]
# Currently we have no feature engineering being performed as we are simply using the raw chanel data. Some ideas we would like to implement:
#
# 1. Pixel standardization
# 2. Usage of other channels created by combining several of the raw features (NDVI or False composite)
# 3. Image alteration to increase the size training data (rotations, zoom in)

# %% [markdown]
# # Train/Test Split

# %% [markdown]
# We will perform an 80/20 split of data for training and testing respectively. This leaves 2,682 images for training and 671 images for testing.

# %%
X_train, X_test, y_train, y_test = train_test_split(images, 
                                                                       phrag_mask_fill, 
                                                                       test_size=0.20, 
                                                                       random_state=42)

# %%
X_train.shape
# Out:
# (2682, 32, 32, 5)

# %% [markdown]
# # UNet in Keras

# %% [markdown]
# UNet is architecture developed by Ronneberger *et al* (https://arxiv.org/abs/1505.04597) created to segment biomedical images. It consists of an encoder and decoder. This network works by taking the image and reducing it into a high dimensional space via system of convolutions and pooling. To create the desired output, a binary segmentation mask, UNet utilizes deconvolutions to expand the high dimensional vector back to the original image dimensions allowing for creation of a high quality image mask.
#
# See:
# 1. https://towardsdatascience.com/understanding-semantic-segmentation-with-unet-6be4f42d4b47
# 2. https://www.tensorflow.org/tutorials/images/segmentation

# %% [markdown]
# Changes:
#
# 1. Based on gridsearch the best optimizer is ADAM
# 2. Based on hyperparameter search: the dropout level should be set to 0.01
# 3. Kernel Intializer was changed from he to xavier normal
# 4. Added l2 regularization to try and decrease the over fitting (0.01 > 0.1)
#
# Highest accuracy on test set: 0.86

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = tf.keras.layers.Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'glorot_normal', padding = 'same',
                               kernel_regularizer=tf.keras.regularizers.l2(0.01))(input_tensor)
    if batchnorm:
        x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    
    # second layer
    x = tf.keras.layers.Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'glorot_normal', padding = 'same',
                               kernel_regularizer=tf.keras.regularizers.l2(0.01))(input_tensor)
    if batchnorm:
        x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    
    return x

# %%
def unet_v1(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    # Build the network
    
    #Encoder
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)
    p1 = tf.keras.layers.Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
    p2 = tf.keras.layers.Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)
    p3 = tf.keras.layers.Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = tf.keras.layers.MaxPooling2D((2, 2))(c4)
    p4 = tf.keras.layers.Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    #Decoder
    u6 = tf.keras.layers.Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = tf.keras.layers.concatenate([u6, c4])
    u6 = tf.keras.layers.Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = tf.keras.layers.Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = tf.keras.layers.concatenate([u7, c3])
    u7 = tf.keras.layers.Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = tf.keras.layers.Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = tf.keras.layers.concatenate([u8, c2])
    u8 = tf.keras.layers.Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = tf.keras.layers.Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = tf.keras.layers.concatenate([u9, c1])
    u9 = tf.keras.layers.Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    #We can use a sigmoid activation function for the final layer as we are doing only one class
    outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = tf.keras.Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
# Parameters based upon the size of the input. 
im_width = 32
im_height = 32
border = 2

# %%
input_img = tf.keras.layers.Input((im_height, im_width,5), name='img')
model = unet_v1(input_img, n_filters=16, dropout=0.01, batchnorm=True)
model.compile(optimizer=tf.keras.optimizers.Adam(), loss="binary_crossentropy", metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 32, 32, 5)]  0
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 16)   736         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 16)   64          conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 16)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 16)   0           activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16, 16, 16)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 32)   4640        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 16, 32)   128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 8, 8, 32)     0           activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 8, 8, 32)     0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 64)     18496       dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 64)     256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 64)     0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 4, 4, 64)     0           activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 4, 4, 64)     0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 4, 4, 128)    73856       dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 4, 4, 128)    512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 4, 4, 128)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 2, 2, 128)    0           activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 2, 2, 128)    0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 2, 2, 256)    295168      dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 2, 2, 256)    1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 2, 2, 256)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 4, 4, 128)    295040      activation_27[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 4, 4, 256)    0           conv2d_transpose_4[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 4, 4, 256)    0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 4, 4, 128)    295040      dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 4, 4, 128)    512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 4, 4, 128)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 8, 8, 64)     73792       activation_29[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 8, 8, 128)    0           conv2d_transpose_5[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 8, 8, 128)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 64)     73792       dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 64)     256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 8, 8, 64)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 16, 16, 32)   18464       activation_31[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 16, 16, 64)   0           conv2d_transpose_6[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 16, 16, 64)   0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 32)   18464       dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 16, 32)   128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 16, 16, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 32, 32, 16)   4624        activation_33[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 32)   0           conv2d_transpose_7[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 32, 32, 32)   0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 32, 32, 16)   4624        dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 32, 32, 16)   64          conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 32, 32, 16)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 32, 32, 1)    17          activation_35[0][0]
# ==================================================================================================
# Total params: 1,179,697
# Trainable params: 1,178,225
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
#This allocates that the network should perform early stopping if the rate of improvement drops below 0.0001
#It saves the best performing network weights to v1_unet.h5
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10, verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    tf.keras.callbacks.ModelCheckpoint('v1_unet.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
#Run the model!
results = model.fit(X_train, y_train, batch_size=64, epochs=50, callbacks=callbacks,\
                    validation_data=(X_test, y_test))
# Out:
# Train on 2682 samples, validate on 671 samples
# Epoch 1/50
# 2368/2682 [=========================>....] - ETA: 0s - loss: 3.5408 - accuracy: 0.6775
# Epoch 00001: val_loss improved from inf to 1.54884, saving model to v1_unet.h5
# 2682/2682 [==============================] - 2s 809us/sample - loss: 3.3028 - accuracy: 0.6892 - val_loss: 1.5488 - val_accuracy: 0.6145
# Epoch 2/50
# 2624/2682 [============================>.] - ETA: 0s - loss: 0.9955 - accuracy: 0.8137
# Epoch 00002: val_loss improved from 1.54884 to 0.88205, saving model to v1_unet.h5
# 2682/2682 [==============================] - 1s 204us/sample - loss: 0.9915 - accuracy: 0.8130 - val_loss: 0.8820 - val_accuracy: 0.7413
# Epoch 3/50
# 2624/2682 [============================>.] - ETA: 0s - loss: 0
50
# 2368/2682 [=========================>....] - ETA: 0s - loss: 0.2983 - accuracy: 0.8939
# Epoch 00041: val_loss did not improve from 0.34069
# 2682/2682 [==============================] - 0s 185us/sample - loss: 0.2981 - accuracy: 0.8945 - val_loss: 0.3875 - val_accuracy: 0.8409
# Epoch 42/50
# 2624/2682 [============================>.] - ETA: 0s - loss: 0.2945 - accuracy: 0.8967
# Epoch 00042: val_loss did not improve from 0.34069
# 2682/2682 [==============================] - 0s 183us/sample - loss: 0.2957 - accuracy: 0.8958 - val_loss: 0.3742 - val_accuracy: 0.8509
# Epoch 43/50
# 2368/2682 [=========================>....] - ETA: 0s - loss: 0.2932 - accuracy: 0.8968
# Epoch 00043: val_loss did not improve from 0.34069
# 2682/2682 [==============================] - 0s 184us/sample - loss: 0.2925 - accuracy: 0.8973 - val_loss: 0.3878 - val_accuracy: 0.8437
# Epoch 44/50
# 2368/2682 [=========================>....] - ETA: 0s - loss: 0.2943 - accuracy: 0.8952
# Epoch 00044: val_loss did not improve from 0.34069
# 2682/2682 [==============================] - 0s 182us/sample - loss: 0.2940 - accuracy: 0.8960 - val_loss: 0.3767 - val_accuracy: 0.8518
# Epoch 45/50
# 2304/2682 [========================>.....] - ETA: 0s - loss: 0.2833 - accuracy: 0.9013
# Epoch 00045: val_loss did not improve from 0.34069
# 2682/2682 [==============================] - 0s 183us/sample - loss: 0.2874 - accuracy: 0.8993 - val_loss: 0.4071 - val_accuracy: 0.8342
# Epoch 00045: early stopping

# %%
#Plot the loss function: See how it changes overtime
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %% [markdown]
# # Model Evaluation

# %%
# load the best model
model.load_weights('v1_unet.h5')

# Evaluate on validation set (this must be equals to the best log_loss)
loss,accuracy = model.evaluate(X_test, y_test, verbose=1)
# Out:
# 671/671 [==============================] - 0s 126us/sample - loss: 0.3407 - accuracy: 0.8702

# %%
print('The model showcases a cost function loss of: {0}'.format(loss))
print('The current pixel accuracy of this basic UNet is: {0}'.format(accuracy))
# Out:
# The model showcases a cost function loss of: 0.34068873875542655
# The current pixel accuracy of this basic UNet is: 0.8701958060264587

# %%
#Visualizing predictions: 
preds_train = model.predict(X_train, verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Need binaries: 
preds_train_thres = (preds_train > 0.5).astype(np.uint16)
preds_test_thres = (preds_test > 0.5).astype(np.uint16)
# Out:
# 2682/2682 [==============================] - 1s 208us/sample
# 671/671 [==============================] - 0s 101us/sample

# %%
preds_train_thres.shape
# Out:
# (2682, 32, 32, 1)

# %%
#Check it out
masked_pred = np.ma.masked_where(preds_train_thres[0,:,:].reshape(32,32) == 0, 
                            preds_train_thres[0,:,:].reshape(32,32))

masked_true = np.ma.masked_where(y_train[0,:,:].reshape(32,32) == 0, 
                            y_train[0,:,:].reshape(32,32))

f, (ax1,ax2) = plt.subplots(1, 2)

#Plot the image
ep.plot_rgb(np.transpose(X_train[0], (2,0,1)),ax =ax1,stretch = True,rgb=[0,1,2],)
#Plot the Mask
ax1.imshow(masked_true, 'jet', interpolation='none', alpha=0.7)
ax1.set_title('Ground Truth')

ep.plot_rgb(np.transpose(X_train[0], (2,0,1)),ax =ax2,stretch = True,rgb=[0,1,2],)
ax2.imshow(masked_pred, 'jet', interpolation='none', alpha=0.7)
ax2.set_title("Train Set Prediction")

plt.show()

# %%
#Check it out
masked_pred = np.ma.masked_where(preds_test_thres[1,:,:].reshape(32,32) == 0, 
                            preds_test_thres[1,:,:].reshape(32,32))

masked_true = np.ma.masked_where(y_test[1,:,:].reshape(32,32) == 0, 
                            y_test[1,:,:].reshape(32,32))

f, (ax1,ax2) = plt.subplots(1, 2)

#Plot the image
ep.plot_rgb(np.transpose(X_test[1], (2,0,1)),ax =ax1,stretch = True,rgb=[0,1,2],)
#Plot the Mask
ax1.imshow(masked_true, 'jet', interpolation='none', alpha=0.7)
ax1.set_title('Ground Truth')

ep.plot_rgb(np.transpose(X_test[1], (2,0,1)),ax =ax2,stretch = True,rgb=[0,1,2],)
ax2.imshow(masked_pred, 'jet', interpolation='none', alpha=0.7)
ax2.set_title("Train Set Prediction")

plt.show()

# %% [markdown]
# ## Hyperparameter Tuning:

# %%
from tensorboard.plugins.hparams import api as hp
import datetime, os
# %reload_ext tensorboard
# !rm -rf ./logs/

# %%
HP_DROPOUT = hp.HParam('dropout', hp.Discrete([0.001,0.01, 0.1]))
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd']))

METRIC_ACCURACY = 'accuracy'

with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
      hp.hparams_config(
        hparams=[HP_DROPOUT, HP_OPTIMIZER],
        metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')])

# %%
def train_test_model(hparams):
    #Set the model
    model = unet_v1(input_img, n_filters=16, dropout=hparams[HP_DROPOUT], batchnorm=True)
    model.compile(optimizer=hparams[HP_OPTIMIZER], loss="binary_crossentropy", metrics=["accuracy"])
    
    #Create a log directory
    logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))  
    
    #initialize the callback:
    callbacks = [
        #tf.keras.callbacks.EarlyStopping(patience=10, verbose=1),
        #tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
        #tf.keras.callbacks.ModelCheckpoint('v1_unet.h5', verbose=1, save_best_only=True, save_weights_only=True),
        tf.keras.callbacks.TensorBoard(logdir),  # log metrics
        hp.KerasCallback(logdir, hparams)]
    
    #fit the model
    model.fit(X_train, y_train, batch_size=64, epochs=50, callbacks=callbacks) 
    _, accuracy = model.evaluate(X_test, y_test)
    
    return accuracy

# %%
session_num = 0
for dropout_rate in (HP_DROPOUT.domain.values):
    for optimizer in HP_OPTIMIZER.domain.values:

        hparams = {
              HP_DROPOUT: dropout_rate,
              HP_OPTIMIZER: optimizer,
              }

        run_name = "run-%d" % session_num
        print('--- Starting trial: %s' % run_name)
        print({h.name: hparams[h] for h in hparams})
        run('logs/hparam_tuning/' + run_name, hparams)
        session_num += 1
# Out:
# --- Starting trial: run-0
# {'dropout': 0.001, 'optimizer': 'adam'}
# Train on 2682 samples
# Epoch 1/50
# 2682/2682 [==============================] - 2s 608us/sample - loss: 0.5033 - accuracy: 0.7551
# Epoch 2/50
# 2682/2682 [==============================] - 0s 170us/sample - loss: 0.4029 - accuracy: 0.8227
# Epoch 3/50
# 2682/2682 [==============================] - 0s 165us/sample - loss: 0
50
# 2682/2682 [==============================] - 0s 171us/sample - loss: 0.3922 - accuracy: 0.8135
# Epoch 39/50
# 2682/2682 [==============================] - 0s 176us/sample - loss: 0.3896 - accuracy: 0.8159
# Epoch 40/50
# 2682/2682 [==============================] - 0s 167us/sample - loss: 0.3894 - accuracy: 0.8161
# Epoch 41/50
# 2682/2682 [==============================] - 0s 163us/sample - loss: 0.3935 - accuracy: 0.8142
# Epoch 42/50
# 2682/2682 [==============================] - 0s 171us/sample - loss: 0.3879 - accuracy: 0.8176
# Epoch 43/50
# 2682/2682 [==============================] - 0s 159us/sample - loss: 0.3868 - accuracy: 0.8164
# Epoch 44/50
# 2682/2682 [==============================] - 0s 162us/sample - loss: 0.3846 - accuracy: 0.8193
# Epoch 45/50
# 2682/2682 [==============================] - 0s 165us/sample - loss: 0.3808 - accuracy: 0.8219
# Epoch 46/50
# 2682/2682 [==============================] - 0s 158us/sample - loss: 0.3818 - accuracy: 0.8205
# Epoch 47/50
# 2682/2682 [==============================] - 0s 162us/sample - loss: 0.3797 - accuracy: 0.8215
# Epoch 48/50
# 2682/2682 [==============================] - 0s 164us/sample - loss: 0.3807 - accuracy: 0.8219
# Epoch 49/50
# 2682/2682 [==============================] - 0s 160us/sample - loss: 0.3788 - accuracy: 0.8235
# Epoch 50/50
# 2682/2682 [==============================] - 0s 154us/sample - loss: 0.3815 - accuracy: 0.8207
# 671/671 [==============================] - 0s 421us/sample - loss: 0.3647 - accuracy: 0.8278
# --- Starting trial: run-2
# {'dropout': 0.01, 'optimizer': 'adam'}
# Train on 2682 samples
# Epoch 1/50
# 2682/2682 [==============================] - 2s 769us/sample - loss: 0.4821 - accuracy: 0.7709
# Epoch 2/50
# 2682/2682 [==============================] - 0s 170us/sample - loss: 0.3959 - accuracy: 0.8255
# Epoch 3/50
# 2682/2682 [==============================] - 0s 173us/sample - loss: 0.3715 - accuracy: 0.8323
# Epoch 4/50
# 2682/2682 [==============================] - 0s 176us/sample - loss: 0.3661 - accuracy: 0.8332
# Epoch 5/50
# 2682/2682 [==============================] - 0s 168us/sample - loss: 0.3413 - accuracy: 0.8486
# Epoch 6/50
# 2682/2682 [==============================] - 0s 170us/sample - loss: 0.3387 - accuracy: 0.8491
# Epoch 7/50
# 2682/2682 [==============================] - 0s 165us/sample - loss: 0.3221 - accuracy: 0.8563
# Epoch 8/50
# 2682/2682 [==============================] - 0s 169us/sample - loss: 0.3142 - accuracy: 0.8630
# Epoch 9/50
# 2682/2682 [==============================] - 0s 169us/sample - loss: 0.3144 - accuracy: 0.8611
# Epoch 10/50
# 2682/2682 [==============================] - 0s 174us/sample - loss: 0.2997 - accuracy: 0.8690
# Epoch 11/50
# 2682/2682 [==============================] - 0s 174us/sample - loss: 0.2913 - accuracy: 0.8740
# Epoch 12/50
# 2682/2682 [==============================] - 0s 185us/sample - loss: 0.2762 - accuracy: 0.8803
# Epoch 13/50
# 2682/2682 [==============================] - 0s 183us/sample - loss: 0.2817 - accuracy: 0.8775
# Epoch 14/50
# 2682/2682 [==============================] - 0s 176us/sample - loss: 0.2639 - accuracy: 0.8858
# Epoch 15/50
# 2682/2682 [==============================] - 0s 180us/sample - loss: 0.2790 - accuracy: 0.8787
# Epoch 16/50
# 2682/2682 [==============================] - 0s 173us/sample - loss: 0.2512 - accuracy: 0.8958
# Epoch 17/50
# 2682/2682 [==============================] - 0s 176us/sample - loss: 0.2278 - accuracy: 0.9037
# Epoch 18/50
# 2682/2682 [==============================] - 0s 177us/sample - loss: 0.2182 - accuracy: 0.9092
# Epoch 19/50
# 2682/2682 [==============================] - 0s 174us/sample - loss: 0.2139 - accuracy: 0.9134
# Epoch 20/50
# 2682/2682 [==============================] - 0s 171us/sample - loss: 0.2035 - accuracy: 0.9168
# Epoch 21/50
# 2682/2682 [==============================] - 0s 173us/sample - loss: 0.1917 - accuracy: 0.9225
# Epoch 22/50
# 2682/2682 [==============================] - 0s 176us/sample - loss: 0.1857 - accuracy: 0.9254
# Epoch 23/50
# 2682/2682 [==============================] - 0s 175us/sample - loss: 0.1790 - accuracy: 0.9275
# Epoch 24/50
# 2682/2682 [==============================] - 0s 175us/sample - loss: 0.1776 - accuracy: 0.9284
# Epoch 25/50
# 2682/2682 [==============================] - 0s 171us/sample - loss: 0.1704 - accuracy: 0.9312
# Epoch 26/50
# 2682/2682 [==============================] - 0s 178us/sample - loss: 0.1773 - accuracy: 0.9282
# Epoch 27/50
# 2682/2682 [==============================] - 0s 173us/sample - loss: 0.1602 - accuracy: 0.9351
# Epoch 28/50
# 2682/2682 [==============================] - 0s 177us/sample - loss: 0.1581 - accuracy: 0.9368
# Epoch 29/50
# 2682/2682 [==============================] - 0s 177us/sample - loss: 0.1632 - accuracy: 0.9342
# Epoch 30/50
# 2682/2682 [==============================] - 0s 176us/sample - loss: 0.1478 - accuracy: 0.9409
# Epoch 31/50
# 2682/2682 [==============================] - 0s 177us/sample - loss: 0.1445 - accuracy: 0.9427
# Epoch 32/50
# 2682/2682 [==============================] - 0s 175us/sample - loss: 0.1399 - accuracy: 0.9438
# Epoch 33/50
# 2682/2682 [==============================] - 0s 172us/sample - loss: 0.1348 - accuracy: 0.9471
# Epoch 34/50
# 2682/2682 [==============================] - 0s 172us/sample - loss: 0.1315 - accuracy: 0.9483
# Epoch 35/50
# 2682/2682 [==============================] - 0s 176us/sample - loss: 0.1286 - accuracy: 0.9493
# Epoch 36/50
# 2682/2682 [==============================] - 0s 172us/sample - loss: 0.1252 - accuracy: 0.9509
# Epoch 37/50
# 2682/2682 [==============================] - 0s 176us/sample - loss: 0.1230 - accuracy: 0.9510
# Epoch 38/50
# 2682/2682 [==============================] - 0s 173us/sample - loss: 0.1219 - accuracy: 0.9525
# Epoch 39/50
# 2682/2682 [==============================] - 0s 173us/sample - loss: 0.1273 - accuracy: 0.9500
# Epoch 40/50
# 2682/2682 [==============================] - 0s 175us/sample - loss: 0.1162 - accuracy: 0.9547
# Epoch 41/50
# 2682/2682 [==============================] - 0s 175us/sample - loss: 0.1110 - accuracy: 0.9566
# Epoch 42/50
# 2682/2682 [==============================] - 0s 173us/sample - loss: 0.1041 - accuracy: 0.9597
# Epoch 43/50
# 2682/2682 [==============================] - 0s 175us/sample - loss: 0.1052 - accuracy: 0.9590
# Epoch 44/50
# 2682/2682 [==============================] - 0s 169us/sample - loss: 0.1028 - accuracy: 0.9598
# Epoch 45/50
# 2682/2682 [==============================] - 0s 177us/sample - loss: 0.0995 - accuracy: 0.9612
# Epoch 46/50
# 2682/2682 [==============================] - 0s 167us/sample - loss: 0.0981 - accuracy: 0.9619
# Epoch 47/50
# 2682/2682 [==============================] - 0s 169us/sample - loss: 0.0995 - accuracy: 0.9614
# Epoch 48/50
# 2682/2682 [==============================] - 0s 170us/sample - loss: 0.0947 - accuracy: 0.9628
# Epoch 49/50
# 2682/2682 [==============================] - 0s 169us/sample - loss: 0.0967 - accuracy: 0.9625
# Epoch 50/50
# 2682/2682 [==============================] - 0s 170us/sample - loss: 0.0985 - accuracy: 0.9618
# 671/671 [==============================] - 0s 442us/sample - loss: 0.4300 - accuracy: 0.8526
# --- Starting trial: run-3
# {'dropout': 0.01, 'optimizer': 'sgd'}
# Train on 2682 samples
# Epoch 1/50
# 2682/2682 [==============================] - 1s 522us/sample - loss: 0.6779 - accuracy: 0.5865
# Epoch 2/50
# 2682/2682 [==============================] - 0s 163us/sample - loss: 0.5701 - accuracy: 0.6789
# Epoch 3/50
# 2682/2682 [==============================] - 0s 170us/sample - loss: 0.5394 - accuracy: 0.7066
# Epoch 4/50
# 2682/2682 [==============================] - 0s 167us/sample - loss: 0.5222 - accuracy: 0.7203
# Epoch 5/50
# 2682/2682 [==============================] - 0s 164us/sample - loss: 0.5102 - accuracy: 0.7291
# Epoch 6/50
# 2682/2682 [==============================] - 0s 169us/sample - loss: 0.5014 - accuracy: 0.7344
# Epoch 7/50
# 2682/2682 [==============================] - 0s 170us/sample - loss: 0.4929 - accuracy: 0.7414
# Epoch 8/50
# 2682/2682 [==============================] - 0s 160us/sample - loss: 0.4883 - accuracy: 0.7448
# Epoch 9/50
# 2682/2682 [==============================] - 0s 164us/sample - loss: 0.4861 - accuracy: 0.7460
# Epoch 10/50
# 2682/2682 [==============================] - 0s 162us/sample - loss: 0.4804 - accuracy: 0.7503
# Epoch 11/50
# 2682/2682 [==============================] - 0s 174us/sample - loss: 0.4766 - accuracy: 0.7538
# Epoch 12/50
# 2682/2682 [==============================] - 0s 156us/sample - loss: 0.4764 - accuracy: 0.7515
# Epoch 13/50
# 2682/2682 [==============================] - 0s 163us/sample - loss: 0.4735 - accuracy: 0.7548
# Epoch 14/50
# 2682/2682 [==============================] - 0s 171us/sample - loss: 0.4698 - accuracy: 0.7579
# Epoch 15/50
# 2682/2682 [==============================] - 0s 164us/sample - loss: 0.4645 - accuracy: 0.7620
# Epoch 16/50
# 2682/2682 [==============================] - 0s 169us/sample - loss: 0.4629 - accuracy: 0.7621
# Epoch 17/50
# 2682/2682 [==============================] - 0s 168us/sample - loss: 0.4616 - accuracy: 0.7644
# Epoch 18/50
# 2682/2682 [==============================] - 0s 158us/sample - loss: 0.4600 - accuracy: 0.7641
# Epoch 19/50
# 2682/2682 [==============================] - 0s 162us/sample - loss: 0.4563 - accuracy: 0.7675
# Epoch 20/50
# 2682/2682 [==============================] - 0s 156us/sample - loss: 0.4528 - accuracy: 0.7697
# Epoch 21/50
# 2682/2682 [==============================] - 0s 160us/sample - loss: 0.4502 - accuracy: 0.7720
# Epoch 22/50
# 2682/2682 [==============================] - 0s 164us/sample - loss: 0.4481 - accuracy: 0.7735
# Epoch 23/50
# 2682/2682 [==============================] - 0s 158us/sample - loss: 0.4443 - accuracy: 0.7768
# Epoch 24/50
# 2682/2682 [==============================] - 0s 165us/sample - loss: 0.4401 - accuracy: 0.7805
# Epoch 25/50
# 2682/2682 [==============================] - 0s 162us/sample - loss: 0.4389 - accuracy: 0.7821
# Epoch 26/50
# 2682/2682 [==============================] - 0s 158us/sample - loss: 0.4348 - accuracy: 0.7840
# Epoch 27/50
# 2682/2682 [==============================] - 0s 163us/sample - loss: 0.4334 - accuracy: 0.7865
# Epoch 28/50
# 2682/2682 [==============================] - 0s 162us/sample - loss: 0.4313 - accuracy: 0.7884
# Epoch 29/50
# 2682/2682 [==============================] - 0s 161us/sample - loss: 0.4254 - accuracy: 0.7935
# Epoch 30/50
# 2682/2682 [==============================] - 0s 162us/sample - loss: 0.4233 - accuracy: 0.7955
# Epoch 31/50
# 2682/2682 [==============================] - 0s 165us/sample - loss: 0.4179 - accuracy: 0.7992
# Epoch 32/50
# 2682/2682 [==============================] - 0s 163us/sample - loss: 0.4136 - accuracy: 0.8027
# Epoch 33/50
# 2682/2682 [==============================] - 0s 163us/sample - loss: 0.4123 - accuracy: 0.8032
# Epoch 34/50
# 2682/2682 [==============================] - 0s 170us/sample - loss: 0.4082 - accuracy: 0.8065
# Epoch 35/50
# 2682/2682 [==============================] - 0s 171us/sample - loss: 0.4092 - accuracy: 0.8047
# Epoch 36/50
# 2682/2682 [==============================] - 0s 171us/sample - loss: 0.4063 - accuracy: 0.8070
# Epoch 37/50
# 2682/2682 [==============================] - 0s 169us/sample - loss: 0.4034 - accuracy: 0.8086
# Epoch 38/50
# 2682/2682 [==============================] - 0s 168us/sample - loss: 0.4009 - accuracy: 0.8111
# Epoch 39/50
# 2682/2682 [==============================] - 0s 164us/sample - loss: 0.3978 - accuracy: 0.8117
# Epoch 40/50
# 2682/2682 [==============================] - 0s 157us/sample - loss: 0.3985 - accuracy: 0.8113
# Epoch 41/50
# 2682/2682 [==============================] - 0s 163us/sample - loss: 0.3943 - accuracy: 0.8145
# Epoch 42/50
# 2682/2682 [==============================] - 0s 157us/sample - loss: 0.3920 - accuracy: 0.8161
# Epoch 43/50
# 2682/2682 [==============================] - 0s 169us/sample - loss: 0.3943 - accuracy: 0.8143
# Epoch 44/50
# 2682/2682 [==============================] - 0s 164us/sample - loss: 0.3944 - accuracy: 0.8130
# Epoch 45/50
# 2682/2682 [==============================] - 0s 160us/sample - loss: 0.3935 - accuracy: 0.8147
# Epoch 46/50
# 2682/2682 [==============================] - 0s 156us/sample - loss: 0.3889 - accuracy: 0.8186
# Epoch 47/50
# 2682/2682 [==============================] - 0s 162us/sample - loss: 0.3845 - accuracy: 0.8210
# Epoch 48/50
# 2682/2682 [==============================] - 0s 156us/sample - loss: 0.3857 - accuracy: 0.8200
# Epoch 49/50
# 2682/2682 [==============================] - 0s 162us/sample - loss: 0.3874 - accuracy: 0.8198
# Epoch 50/50
# 2682/2682 [==============================] - 0s 156us/sample - loss: 0.3816 - accuracy: 0.8227
# 671/671 [==============================] - 0s 450us/sample - loss: 0.3675 - accuracy: 0.8269
# --- Starting trial: run-4
# {'dropout': 0.1, 'optimizer': 'adam'}
# Train on 2682 samples
# Epoch 1/50
# 2682/2682 [==============================] - 2s 591us/sample - loss: 0.5370 - accuracy: 0.7193
# Epoch 2/50
# 2682/2682 [==============================] - 0s 170us/sample - loss: 0.4292 - accuracy: 0.7909
# Epoch 3/50
# 2682/2682 [==============================] - 0s 176us/sample - loss: 0.3787 - accuracy: 0.8266
# Epoch 4/50
# 2682/2682 [==============================] - 0s 173us/sample - loss: 0